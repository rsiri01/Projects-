# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
auto = pd.read_csv('Automobile.csv')

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.histplot(auto['city_mpg'], kde=False);

# %%
sns.histplot(auto['highway_mpg'], kde=False);

# %%
sns.histplot(auto['price'], kde=False);

# %%
sns.histplot(auto['horsepower'], kde=False);

# %%
sns.jointplot(x='engine_size',y='price',data=auto);

# %%
sns.jointplot(x='horsepower',y='price',data=auto)

# %%
sns.jointplot(x='engine_size',y='city_mpg',data=auto)

# %%
sns.jointplot(x='engine_size',y='highway_mpg',data=auto)

# %%
sns.swarmplot(x='body_style',y='horsepower',data=auto);
# Out:
# /Users/Rahul/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/Rahul/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='body_style',y='price',data=auto);
# Out:
# /Users/Rahul/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='drive_wheels',y='price',data=auto, jitter=True);

# %%
sns.stripplot(x='drive_wheels',y='horsepower',data=auto, jitter=True);

# %%
sns.swarmplot(x='fuel_type',y='price',data=auto);

# %%
sns.swarmplot(x='fuel_type',y='horsepower',data=auto);
# Out:
# /Users/Rahul/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='drive_wheels',y='horsepower',data=auto, hue=auto['fuel_type']);

# %%
sns.boxplot(x='body_style',y='city_mpg',data=auto, hue=auto['fuel_type']);

# %%
sns.barplot(x='body_style', y='horsepower', data=auto, hue=auto['fuel_type']);

# %%
sns.barplot(x='body_style', y='price', data=auto, hue=auto['fuel_type']);

# %%
sns.barplot(x='body_style', y='city_mpg', data=auto, hue=auto['fuel_type']);

# %%
sns.barplot(x='body_style', y='highway_mpg', data=auto, hue=auto['fuel_type']);

# %%
sns.countplot(x='body_style', data=auto, hue=auto['fuel_type']);

# %%
sns.countplot(x='drive_wheels', data=auto, hue=auto['fuel_type']);

# %%
sns.catplot(x="body_style",
               y = "price",
               hue="fuel_type", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %%
sns.catplot(x="body_style",
               y = "horsepower",
               hue="fuel_type", 
               col="drive_wheels", 
               data=auto, 
               kind="box");

# %%
sns.lmplot(y="price", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="engine_size", data=auto);

# %%
sns.lmplot(y="horsepower", x="city_mpg", data=auto);

# %%
sns.lmplot(y="horsepower", x="highway_mpg", data=auto);

# %%
efficient = auto[auto['city_mpg'] > 40];
efficient
# Out:
#     symboling  normalized_losses       make fuel_type aspiration  \
# 17          2                121  chevrolet       gas        std
# 29          2                137      honda       gas        std
# 87          1                128     nissan    diesel        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 17             two  hatchback          fwd           front        88.4  ...
# 29             two  hatchback          fwd           front        86.6  ...
# 87             two      sedan          fwd           front        94.5  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 17           61         2bbl  2.91    3.03               9.5         48
# 29           92         1bbl  2.91    3.41               9.6         58
# 87          103          idi  2.99    3.47              21.9         55
#
#     peak_rpm city_mpg  highway_mpg  price
# 17      5100       47           53   5151
# ...

# %%
power = auto[auto['horsepower'] > 200];
power
# Out:
#      symboling  normalized_losses     make fuel_type aspiration  \
# 46           0                115   jaguar       gas        std
# 123          3                128  porsche       gas        std
# 124          3                128  porsche       gas        std
# 125          3                128  porsche       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 46              two        sedan          rwd           front       102.0
# 123             two      hardtop          rwd            rear        89.5
# 124             two      hardtop          rwd            rear        89.5
# 125             two  convertible          rwd            rear        89.5
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 46   ...          326         mpfi  3.54    2.76              11.5        262
# 123  ...          194         mpfi  3.74    2.90               9.5        207
# ...

# %%
expensive = auto[auto['price'] > 40000];
expensive
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...
